# %% [markdown]
# ![Analytics lab](./figures/analytics_lab.png)

# %% [markdown]
# ##`Team #9`
# - Ana Luísa Lopes
# - Paul Edge
# - Rafael Caneiro

# %% [markdown]
# ## Challenge #1: Gotta Cluter’em All!
#
# What’s expected from this challenge are the following 3 key points:
#
# **1.** Clustering items by similarity and naming the clusters
# <div><img src="./figures/analytics_lab_clustering.png" style="height: 300px; margin: 20px"/></div>
#
# **2.** Using natural language processing to identify strings that represent the same item type and cluster them for us to uniformize the description
# <div><img src="./figures/analytics_lab_items_1.png" style="height: 250px; margin: 20px"/></div>
#
# **3.**
# Eliminate redundancies (a material that has been inadvertently created in the database more than once over the years) in the material master data and output the unique IDs of the most similar descriptions
# <div><img src="./figures/analytics_lab_items_2.png" style="height: 300px; margin: 20px"/></div>

# %% [markdown]
# ## Datasets
# **1. matList_pt.csv**
# This dataset contains the list of all materials that currently exist in SAP. The file is composed of 4 columns:
#
# - **Material (Col. A)** – The unique ID of each material
# - **Txt.brv.material (Col. B)** – Brief description of the material
# - **Texto Dados Basicos (Col. C)** – The full description of the material
# - **UM basica (Col. D)** – The standard purchasing unit of the material (for example - kilogram weights, boxes, pairs and so on…)
#
# **2. matList_es.csv**
# The material list in Spanish. Please note that not all materials have a Spanish translation. The file has the same structure as matList_pt.csv
#
# **3. matList_en.csv**
# The material list in English. Please note that not all materials have an English translation. The file has the same structure as matList_pt.csv
#
# **4. purchaseInfo.csv (283.974 entries)**
# This dataset is the log of the movements of the materials by month over a period of 36 months. The file is composed of the following information:
#
# - **Cod Material (Col. A)** – The material ID
# - **Material (Col. B)** – The material description
# - **Fornecedor (Col. C)** – The supplier code
# - **UN (Cod. D)** – The buying organization inside EDP
# - **Mes (Col. E)** – The month in which the material was delivered
# - **Valor (Col. F)** – The value in euros of the delivery

# %% [markdown]
# ## First Look
#
# ### Loading the data
# The file has some broke lines with an irregular number of columns. So the first step would be to find out the maximum number of columns.

# %%
#  Define HOME and Sharepoint Path
from pathlib import Path
PATH = Path(Path.home(), Path("EDP/O365_ANALYTICS LAB TEAM #9 - Documentos/General"))

file = Path(PATH, "./data/raw/matList_pt.csv") 
with open(file, encoding="utf8") as infile:
    data = infile.readlines()
    
    max_count = 0
    for i in data:
        count = i.count("|")
        if count > max_count:
            max_count = count
            
print(max_count)
# Out:
# 7

# %% [markdown]
# The maximum number of pipe characters found was 7, meaning it will be necessary to import the file with an "8 columns schema".

# %%
import pandas as pd
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = 1000

col_names = ["c0", "c1", "c2", "c3", "c4", "c5", "c6", "c7"]

df = pd.read_csv(file,
                 sep="|",
                 names=col_names,
                 quoting=3,
                 skiprows=1,
                 lineterminator="\r")
df.head(100)
# Out:
# C:\Users\rco\anaconda3\envs\h2o3\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              c0                                        c1  \
# 0   \n"10044864          VENTILADOR SIEMENS PFK 355/102 C
# 1    \n10044865     BOBINA SIEMENS 3AX1101-2F 220VCC (Y2)
# 2    \n10044868               PRESSOSTATO TRAFAG 8730.101
# 3    \n10044869           PALMILHA ASTRA GEL INSOLE TM 45
# 4    \n10044870              BOBINA ELETRO FREIO ELEVADOR
# 5    \n10044871     SAPATO PSH PROT MEC BIQ N/MET 46 EDPP
# 6    \n10044872  LUVAS PROT QUIMICA KCL BUTOJECT 898 Nº10
# 7    \n10044873      DISJUNTOR SIEMENS 3AK3438-5JF55-5CA2
# 8    \n10044874           PALMILHA ASTRA GEL INSOLE TM 41
# 9    \n10044875           PALMILHA ASTRA GEL INSOLE TM 42
# 10   \n10044876    CARRO APOIO P/EXTRACAO CEF CELAS GT3-4
# 11   \n10044877           PALMILHA ASTRA GEL INSOLE TM 43
# 12   \n10044878           PALMILHA ASTRA GEL INSOLE TM 44
# 13   \n10044879           PALMILHA ASTRA GEL INSOLE TM 36
# 14   \n10044880           PALMILHA ASTRA GEL INSOLE TM 37
# 15   \n10044881           PALMILHA ASTRA GEL INSOLE TM 38
# 16   \n10044882           PALMILHA ASTRA GEL INSOLE TM 39
# 17   \n10044883           PALMILHA ASTRA GEL INSOLE TM 40
# 18   \n10044884                  LUVAS DESCARTAVEIS LATEX
# 19   \n10044885     LUVAS DESCARTAVEIS NITRILO AZ - TAM M
# 20   \n10044886    LUVAS PROT MEC 5D PELE CAV T8-230 EDPP
# 21   \n10044887    LUVAS PROT MEC 5D PELE CAV T7-230 EDPP
# 22   \n10044888              ACTUADOR H&B RSD10-50/100 ##
# 23   \n10044889      FATO MACACO PROT IGNIFUGA XXXXL EDPP
# 24   \n10044890          TELECOORDINOMETRO TELELOT VDD2V4
# 25   \n10044891     LUVAS PROT MEC MALHA 5D PT TAM 8 EDPP
# 26   \n10044892                PULLOVER LA VIRGEM XS EDPP
# 27   \n10044893     POLO PROT TERCA ARCO ELECT XXXXL EDPP
# 28   \n10044894           CAMISA PROT IGNIFUGA XXXXL EDPP
# 29   \n10044895       FATO MACACO C/CAPUZ TYVEK C XL EDPP
# 30   \n10044896        FATO MACACO C/CAPUZ TYVEK C M EDPP
# 31   \n10044897        FATO MACACO C/CAPUZ TYVEK C L EDPP
# 32   \n10044898      FATO MACACO C/CAPUZ TYVEK C XXL EDPP
# 33   \n10044899                   T-SHIRT ALGODAO XS EDPP
# 34   \n10044901                      POLO ALGODAO XS EDPP
# 35   \n10044902        CALCA PROT IGNIFUGA 68 (62PT) EDPP
# 36   \n10044903    CASACO PROT IGNIFUGA XXXXL (60PT) EDPP
# 37   \n10044904           PALMILHA ASTRA GEL INSOLE TM 35
# 38   \n10044908                    FATO MACACO XXXXL EDPP
# 39   \n10044909    LUVAS PROT QUIMICA 5D CR 450 Nº 8 EDPP
# 40  \n"10044910     POLO DISJ SIEMENS 3AP1FG 72.5KV 2000A
# 41   \n10044911       CALHA PONTE ROLANTE VAHLE KSLT 4/60
# 42   \n10044912    RODA TURBINA GRUPOS REVERSIVEIS FRADES
# 43   \n10044916  MODULO ABB UA C096AE01 HIEE300794R00 CEF
# 44   \n10044917         ELECTRO-EMBRAIAGEM US MOTORS EDVO
# 45   \n10044918   LUVAS PROT QUIMICA 5D CR 450 Nº 10 EDPP
# 46   \n10044919  BOTA PROT MEC BIQ N/MET RES AGUA 46 EDPP
# 47  \n"10044920   JUNTA BARRAMENTO SIMELECTRO 18KV 3050MM
# 48  \n"10044921   JUNTA BARRAMENTO SIMELECTRO 18KV 2960MM
# 49   \n10044924      CABECA CILINDRO A.COPCO 1503-0381-80
# 50   \n10044925                  TURBINA BOMBA SUBMERSIVA
# 51   \n10044926   FIEIRA VEDANTE MANGA VALV GUARDA M-8436
# 52   \n10044928                  DETETOR HONEYWELL STD720
# 53   \n10044929            PRE FILTRO ALSTOM R408469P0002
# 54   \n10044930              SEGMENTO ALSTOM R102515P0001
# 55   \n10044932      BOMBA CENT EFAFLU CJG 50-250 C/MOTOR
# 56   \n10044935     TRAVESSIA HSP SETFT 1550-420-16 400KV
# 57   \n10044936    CONVERSOR ISKRA MIRS485 0-30VDC 4-20MA
# 58   \n10044937       FRANCALETE P/ CAPACETE PROT ISOL 3M
# 59   \n10044938         DESCARREGADOR SBRTEN ASEA XAF 53B
# 60   \n10044940     TAMBOR CON FILT BRAILLON TIPO 5 Nº513
# 61   \n10044941     TAMBOR CON FILT BRAILLON TIPO 3 Nº371
# 62   \n10044942          MODULO ENT ANALG EFACEC MAP 8081
# 63   \n10044943                MODULO CPU EFACEC MAP 8000
# 64  \n"10044944    BORNE CHASSIS CE/CD/CT P/MASTERPACT NW
# 65  \n"10044945             CONTACTO SDE P/ MASTERPACT NW
# 66   \n10044946                JOELHEIRAS PROTECAO - EDPP
# 67   \n10044947  MODULO FONTE ALM EFACEC MAP 8010 V4 24CC
# 68   \n10044948            MODULO ENT DIG EFACEC MAP 8021
# 69  \n"10044949        MODULO LNG RETARDAMTO P/MICROLOGIC
# 70  \n"10044950         MOTOR REARME MCH P/ MASTERPACT NW
# 71  \n"10044951   BORNE CHASSIS ACESS+AUX P/MASTERPACT NW
# 72  \n"10044952      BLOCO 4 CONTACTOS OF P/MASTERPACT NW
# 73  \n"10044953            BORNE CHASSIS P/ MASTERPACT NW
# 74   \n10044955  FILTRO 3M 6098 AXP3R MASC PROT RESP EDPP
# 75  \n"10044956       BOBINA MN P/DISJUNTOR MASTERPACT NW
# 76  \n"10044957    BOBINA MX PARA DISJUNTOR MASTERPACT NW
# 77  \n"10044958         MODULO DISPARADOR MICROLOGIC 5.0A
# 78   \n10044959    ARMACAO OCULOS PROT UVEX MERCURY 56-19
# 79   \n10044960     FILTRO COMPLETO PALL SCY-1001-G12-H4Y
# 80   \n10044961                VALV MCH ESF PVC PN10 DN80
# 81   \n10044962                 PULLOVER LA VIRGEM S EDPP
# 82  \n"10044963     SAPATO PSH PROT MEC BIQ N/MET 36 EDPP
# 83   \n10044965                VALV MCH ESF PVC PN16 DN80
# 84   \n10044966              VALV MN DIAF SAUNDERS A DN80
# 85   \n10044967             VALV MN DIAF SAUNDERS A DN100
# 86   \n10044968             VALV ANTI-RETN SAUNDERS DN100
# 87   \n10044970       FATO IMPERMEAVEL AM BANDA RF S EDPP
# 88   \n10044972        CAPACETE PROTECAO ISOLANTE BR EDPP
# 89   \n10044973                TRANSF INT WATTSUD IWR 10K
# 90   \n10044975    DESCARREGADOR SBRTEN ASEA XAF 50B 60KV
# 91  \n"10044976       BOTA P/BAIXA TEMP BI PA ACO 38 EDPP
# 92   \n10044977             CAIXA REDUTORA MAAG PUVA 3-28
# 93   \n10044978    CONDENSADOR TRENCH TEC69 10000PF 60KV#
# 94   \n10044981  PERMUTADOR P/MOTOR EFACEC AV/RA 560 L8 F
# 95   \n10044982        VENTILADOR P/MOTOR SEPSA QWG560HB4
# 96   \n10044983  VENTILADOR P/MOTOR EFACEC AT2 630 L8 FS4
# 97   \n10044985            ANEL Z18-180 MOTOR WEG MGW630A
# 98   \n10044986                BOBINA TRENCH 0.2MH 800A #
# 99   \n10044987     ARMARIO COMD P/DISJ EFACEC HPGE 9-14C
#
#                                                                                                                                                                                                                                              c2  \
# 0                                                                                                                 VENTILADOR SIEMENS, REF: PFK 355/102 C, POTENCIA: 150W, TENSAO: 230V; 50/60HZ (PECA DE RESERVA DA CELA NXAIR P, VILA NOVA G4)
# 1                                                                                            BOBINE SIEMENS, REF: 3AX1101-2F, TENSAO: 220VCC, UTILIZACAO: COMO BOBINE DE ABERTURA POR ENVIO DE TENSAO (Y2), PARA DISJUNTORES SIEMENS, TIPO: 3AK
# 2                                                        PRESSOSTATO TRAFAG, TIPO: 8730.101, CONTROLADOR DE PRESSAO E DENSIDADE DE SF6, FAIXA DE PRESSAO: -1 A 10BAR, FAIXA DE TEMPERATURA: -25 A +55(o)C, PRESSAO FUNCIONAMENTO: 20(o)C/5.7BAR
# 3                                                                                                                                                                    PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 45
# 4                                                                                                                                     BOBINA ELETRO FREIO DO ELEVADOR SALAMONDE DIAMETRO INTERIOR: 80MM, DIAMETRO EXTERIOR: 125MM, ALTURA 110MM
# 5                                                                               SAPATO PROTEÇÃO MECÂNICA COM BIQUEIRA NÃO METÁLICA TAMANHO 46, CONFORME A FT 1.6.1, PALMILHA ANTIPERFURAÇÃO NÃO METÁLICA E SOLA ANTIDERRAPANTE - EDP PRODUÇÃO -
# 6                                                                                                                                                                              LUVAS PARA PROTECCAO QUIMICA  KCL, BUTOJECT 898, N(o)10, CAT III
# 7                                                                                                                        DISJUNTOR SIEMENS, REF: 3AK3438-5JF55-5CA2, EM MODO EXTRATIVEL (DISJUNTOR DO ALTERNADOR DO G4 DA CENTRAL DE VILA NOVA)
# 8                                                                                                                                                                    PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 41
# 9                                                                                                                                                                    PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 42
# 10                                                                                                       CARRO DE APOIO SIEMENS, PARA EXTRACAO DE DISJUNTOR DO CONVERSOR ELECTRONICO DE FREQUENCIA (CEF), DAS CELAS GT3-4, DA CENTRAL DE FRADES
# 11                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 43
# 12                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 44
# 13                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 36
# 14                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 37
# 15                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 38
# 16                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 39
# 17                                                                                                                                                                   PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 40
# 18                                                                                                                                                                                                                     LUVAS DESCARTAVEIS LATEX
# 19                                                                                        LUVAS DESCARTÁVEIS 100% EM NITRILO AZUL, PARA MANUSEAMENTO DE TODO O TIPO DE PRODUTOS QUÍMICOS, ESPECIFICAS PARA USO EM LABORATÓRIO COM PÓ, TAMANHO M
# 20                                                                                                                              LUVAS DE PROTECCAO MECANICA COM CINCO DEDOS EM PELE DE CAVALO (TIPO CHEFE), TAMANHO: 8 (230MM) - EDP PRODUCAO -
# 21                                                                                                                              LUVAS DE PROTECCAO MECANICA COM CINCO DEDOS EM PELE DE CAVALO (TIPO CHEFE), TAMANHO: 7 (230MM) - EDP PRODUCAO -
# 22                                                                                                                                                              ACTUADOR HARTMANN&BRAUN, REF: RSD10-50/100, PARA VALVULA DE VAPOR DE ATOMIZACAO
# 23                              FATO MACACO, PROTECAO IGNIGUGA, ARCO ELECTRICO E ANTI ESTATICA, COM FECHO DE CORRER NAO METALICO ABERTURA NOS 2 EXTREMOS, COM LOGOTIPO, CONFORME DPS 38.008-11 . EDP (FT 1.0.8) TAMANHO XXXXL) - EDP PRODUCAO -
# 24                                                                                                                                                                               TELECOORDINOMETRO TELELOT, TIPO: VDD2V4, DE 2 EIXOS HUGGENBERG
# 25                                                                                                                                                           LUVAS DE PROTECCAO MECANICA EM MALHA DE COR PRETA, COM 5 DEDOS, 8 - EDP PRODUCAO -
# 26                                                                                      PULLOVER COLARINHO REDONDO, TECIDO 100% LA VIRGEM, COM LOGOTIPO, COR AZUL-MARINHO, CONFORME DPS 38.008-11 # EDP (FT 1.0.12) TAMANHO XS - EDP PRODUCAO -
# 27                                              POLO EM TECIDO COM PROTECCAO TERMICA CONTRA O CALOR E CHAMA, ANTI-ESTATICA, CONTRA O ARCO ELECTRICO, TAMANHO XXXXL, EM CONFORMIDADE COM FICHA TECNICA EDP: FT 1.0.2 (FEV 2007) - EDP PRODUCAO -
# 28                             CAMISA DE TRABALHO, PROTECAO IGNIGUGA, ARCO ELECTRICO E ANTI ESTATICA, UM BOLSO DIANTEIRO NO PEITO ESQUERDO C/LOGOTIPO, CONFORME DPS 38.008-11 . EDP (FT 1.0.4) TAMANHO XXXXL (N(o)60 PORTUGAL) - EDP PRODUCAO -
# 29                                                                                                                                 FATO MACACO, COM CAPUZ, TYVEK-PROTECH MOD. C, PARA PROTECCAO QUIMICA E BIOLOGICA TAMANHO XL - EDP PRODUCAO -
# 30                                                                                                                                  FATO MACACO, COM CAPUZ, TYVEK-PROTECH MOD. C, PARA PROTECCAO QUIMICA E BIOLOGICA TAMANHO M - EDP PRODUCAO -
# 31                                                                                                                                  FATO MACACO, COM CAPUZ, TYVEK-PROTECH MOD. C, PARA PROTECCAO QUIMICA E BIOLOGICA TAMANHO L - EDP PRODUCAO -
# 32                                                                                                                                FATO MACACO, COM CAPUZ, TYVEK-PROTECH MOD. C, PARA PROTECCAO QUIMICA E BIOLOGICA TAMANHO XXL - EDP PRODUCAO -
# 33                                                                                                                                                                           T-SHIRT EM 100% ALGODAO, COM LOGOTIPO, TAMANHO XS - EDP PRODUCAO -
# 34                                                                                                                                                 POLO EM 100% ALGODAO, MANGA COMPRIDA, GOLA E BOTOES, COM LOGOTIP TAMANHO XS - EDP PRODUCAO -
# 35             CALCA DE TRABALHO, PROTECAO IGNIFUGA, ARCO ELECTRICO E ANTI ESTATICA, DUAS BANDAS REFLECTORAS NAS PERNAS DE 25MM DE LARGURA, COM LOGOTIPO, CONFORME DPS 38.008-11 . EDP (FT 1.0.2) TAMANHO 68 (N(o)62 PORTUGAL) - EDP PRODUCAO -
# 36         CASACO DE TRABALHO, PROTECAO IGNIGUGA, ARCO ELECTRICO E ANTI ESTATICA, DUAS BANDAS REFLECTORAS NAS MANGAS DE 25MM DE LARGURA, COM LOGOTIPO, CONFORME DPS 38.008-11 . EDP (FT 1.0.2) TAMANHO XXXXL (N(o)60 PORTUGAL) - EDP PRODUCAO -
# 37                                                                                                                                                                  PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL, TAMANHO 35
# 38                                                              FATO DE MACACO, TECIDO 100% ALGODAO, COM FECHO DE CORRER NAO METALICO ABERTURA NOS 2 EXTREMOS, FRENTE COM 2 BOLSOS, 1 BOLSO ATRAS, COM LOGOTIPO, TAMANHO XXXXL - EDP PRODUCAO -
# 39                                                                                                             LUVAS DE PROTECCAO QUIMICA, COM CINCO DEDOS, EM BORRACHA SINTETICA (NEOPRENE) ASTM D1418-72 A 450MM, TAMANHO: 8 - EDP PRODUCAO -
# 40                                                                                                     POLO PARA DISJUNTOR SIEMENS, TIPO: 3AP1FG, U NOMINAL: 72.5KV, I NOMINAL: 2000A (LINHA DE 60 KV; TR2 (60/30KV), TR2 (60/3.5 KV) DE RAIVA)
# 41                                                                                                                        CALHA PARA PONTE ROLANTE VAHLE, REF: KSLT 4/60, INTENSIDADE: 60A, TENSAO MAX: 500V, COMPRIMENTO: 4M (PONTES ROLANTES)
# 42                                                                                                                                                         RODA DA TURBINA DE RESERVA, DOS GRUPOS REVERSIVEIS DE FRADES, FORNECDOR: VOITH HYDRO
# 43                                                    MÓDULO ABB, TIPO: UA C096 AE01, REF: HIEE300794R0001, PARA CONVERSOR DE ELETROFREQUÊNCIA (ABB MEGADRIVE - LCI.SO, ANO FABRICO: 2002, TIPO: A0606-584N452, REF: HI2001515, SERIAL Nº: 362)
# 44  ELECTRO-EMBRAIAGEM US MOTORS, TIPO: EDVO, CORRENTE: 2.88A, VELOCIDADE DE TRABALHO: 50-1375RPM, POTENCIA: 5CV, MODELO: 80, DE FABRICO ESPECIAL COM A REF: 9500223-3.73-KW-245-M, UNIDADE ESPECIFICADA COMO UNIDADE DE CORRENTE, (KKS: 10HFB)
# 45                                                                                                            LUVAS DE PROTECCAO QUIMICA, COM CINCO DEDOS, EM BORRACHA SINTETICA (NEOPRENE) ASTM D1418-72 A 450MM, TAMANHO: 10 - EDP PRODUCAO -
# 46                                                             BOTA PROTECAO MECANICA, COM BIQUEIRA NAO METALICA, RESISTENTE A AGUA, TAMANHO 46, CONFORME FT 1.6.2, PALMILHA ANTIPERFURACAO NAO METALICA E SOLA ANTIDERRAPANTE - EDP PRODUCAO -
# 47                                                                                  JUNTA PARA BARRAMENTO SIMELECTRO DE 18KV, TIPO: PG 41054L, JUNTA ""LABIO"" SINTETICA, Oe: 3050MM, PART N(o): 42521751, ITEM: N(o) 16 NO DESENHO 8127127-P06
# 48                                                                                   JUNTA PARA BARRAMENTO SIMELECTRO DE 18KV, TIPO: PG 41054, JUNTA ""LABIO"" SINTETICA, Oe: 2960MM, PART N(o): 42552356, ITEM: N(o) 17 NO DESENHO 8127127-P06
# 49                                                                                                                                CABECA CILINDRO COMPLETO, REF: 1503-0381-80, COMPRESSORES DE REGULACAO ATLAS COPCO, GRUPOS 1 E 2 DE SALAMONDE
# 50                                                                                                                                                          TURBINA DA BOMBA SUBMERSIVA APLICADA NO ESGOTO DE  DRENAGEM DA CENTRAL DE SALAMONDE
# 51                                    FIEIRA DO PERFIL M-8436 DA FLEXOCOL, FIEIRA DO PERFIL DE BORRACHA PARA JUNTA DA MANGA DE DESMONTAGEM VALVULA DE GUARDA DO GRUPO DE LABRUJA. PERFIL DE BORRACHA NATURAL, COMPRIMENTO: 2M, DUREZA: 70 SHORE
# 52                                                                                                                                                                  DETETOR HONEYWELL, REF: STD720-E1AC4AS-1-C-AHB-11S-B-10A0-F1, SAIDA: 4-20MA
# 53                                                                                                      PRE-FILTRO ALSTOM (FINE STRAINER COMPLETE), DES: HTGD690102P9 PART N(o): R408469P0002, (KKS:10MAA11AA001 - VALVULA ADMISSAO TURBINA AP)
# 54                                                                                                      SEGMENTO ALSTOM (SEGMENT RING), DESENHO: HTGD690102P10, PART N(o) R102515P0001,(KKS:10MAA11AA001 - P/VALVULA DE ADMISSAO DA TURBINA AP)
# 55                                                                   BOMBA CENTRIFUGA EFAFLU, TIPO: CJG 50-250, N(o): 101110602, CAUDAL: 55M3/H, HM 76M, VELOCIDADE: 2900RPM, POTENCIA MOTOR: 30KW, LIGACAO: 380/660 V, COTA: 04:00M, KKS: GHM,
# 56                                                                    TRAVESSIA HSP, TIPO SETFT 1550-420-1600 E3 SPEZ. U: 420KV, BIL: 1550KV, FR 50/60HZ, ANG MAX: 35(o)C, PESO: 700KG, IR: 1600A, SIL: 1175KV, N(o) SERIE 3232654 KKS: 30BAT10
# 57                                                                                       CONVERSOR ISKRA, TIPO: MIRS485 AUX.EDC/AC M1456-49824, 0-30VDC, 4-20MA, ALIMENTACAO UNIVERSAL, COMUNICACAO RS485 10/20/30/40BUD/BUE, 90BUJ/BUK/BUR/BUS
# 58                                                                                                                                                                                            FRANCALETE PARA CAPACETE DE PROTEÇÃO ISOLANTE, 3M
# 59                                                                                                                                                DESCARREGADOR DE SOBRETENSOES ASEA, TIPO: XAF 53B, TENSAO NOMINAL: 60 KV (KKS: 90AFH11/12/13)
# 60                                                                                                                                                                     TAMBOR CONICO DO FILTRO BRASSERT BRAILLON, SERIE:STRAINER, TIPO 5, N(o)5
# 61                                                                                                                                                                     TAMBOR CONICO DO FILTRO BRASSERT BRAILLON, SERIE:STRAINER, TIPO 3, N(o)3
# 62                                                                                                                                      MODULO DE ENTRADAS ANALOGICAS EFACEC, TIPO: MAP 8081, N(o) SERIE: 656121 (AUTOMATO GRUPO, REF: CLP500E)
# 63                                                                                                                                                         MODULO CPU EFACEC, TIPO: MAP 8000, N(o) SERIE: 641359 (AUTOMATO GRUPO, REF: CLP500E)
# 64                                                                                                    BORNE SCHNEIDER, DE CHASSIS, TIPO: CE/ CD/CT, PARA MASTERPACT NW PART N(o) 33170, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 65                                                                                                                   CONTACTO SCHNEIDER, TIPO: SDE, PARA MASTERPACT NW, PART N(o) 47915 (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 66                                                                                                                                                                                                JOELHEIRAS DE PROTECCAO - ROTULA, PARA A EDPP
# 67                                                                                                                                              MODULO FONTE DE ALIMENTAÇÃO 24VCC EFACEC, TIPO: MAP 8010 OPCAO 4 (AUTÓMATO GRUPO, REF: CLP500E)
# 68                                                                                                                                        MODULO DE ENTRADAS DIGITAIS EFACEC, TIPO: MAP 8021, N(o) SERIE: 657078 (AUTOMATO GRUPO, REF: CLP500E)
# 69                                                                                    MODULO SCHNEIDER, LONGO RETARDAMENTO, STANDARD PLUG: 0.4 A 1XIr, P/ MICROLOGIC, PART N(o): 33542, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHH; 90BLC)
# 70                                                                                                        MOTOR SCHNEIDER, DE REARME, 100/130 VCC, PARA MASTERPACT NW, PART N(o): 47890 (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 71                                                                                                         BORNE SCHNEIDER, DE CHASSIS, ACESS+AUX, PARA MASTERPACT NW, PART N(o) 47849, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 72                                                                                                            BLOCO SCHNEIDER, COM 4 CONTACTOS OF, PARA MASTERPACT NW, PART N(o) 47887, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 73                                                                                                                    BORNE SCHNEIDER, DE CHASSIS, PARA MASTERPACT NW, PART N(o) 47850, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 74                                                                                                                                                          FILTRO 3M, TIPO: 6098 AXP3R, PARA MASCARA DE PROTECAO RESPIRATORIA - EDP PRODUCAO -
# 75                                                                                         BOBINA SCHNEIDER, TIPO: MN, DESLIGAR MINIMA TENSAO, PARA DISJUNTOR MASTERPACT NW, PART N(o): 33670, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BLC)
# 76                                                                                        BOBINA SCHNEIDER, TIPO: MX, EMISSAO CORRENTE, PARA  DISJUNTOR MASTERPACT NW, PART N(o) 33661, (KKS: 10/20/30/40BFA...BFH; 90BHF; 90BHG; 90BHD; 90BLC)
# 77                                                                                                                  MODULO DISPARADOR SCHNEIDER, TIPO: MICROLOGIC 5.0A, PART N(o): 33072, (KKS: 10/20/30/40BFA...BFH; 90BHF/90BHG/90BHD; 90BLC)
# 78                                                                                                                                                                   ARMACAO PARA OCULOS DE PROTECAO UVEX, TIPO: MERCURY, REF: PC CRISTAL 56-19
# 79                                                                                                         FILTRO COMPLETO PALL HOUSING, REF: SCY 1001 G12 H4Y, EM POLIPROPILENO. COM ELEMENTO FILTRANTE, REF: MCY 1001 J100 H13 (KKS: QCA/QCC)
# 80                                                                                                                            VALVULA MACHO ESFERICO, EM PVC, PN10, DN80, COM COLARINHO PARA MONTAR, VALVULA DA JASON, TIPO: 370 OU EQUIVALENTE
# 81                                                                                      PULLOVER COLARINHO REDONDO, TECIDO 100% LA VIRGEM, COM LOGOTIPO, COR AZUL-MARINHO, CONFORME DPS 38.008-11 # EDP (FT 1.0.12) TAMANHO S  - EDP PRODUCAO -
# 82                                                                            SAPATO PROTECAO MECANICA COM BIQUEIRA NAO METALICA TAMANHO 36,\nCONFORME A FT 1.6.1, PALMILHA ANTIPERFURACAO NAO METALICA E SOLA\nANTIDERRAPANTE - EDP PRODUCAO -
# 83                                                                                                                                                                    VALVULA MACHO ESFERICO +GF+, EM PVC, PN16 DN80, COM COLARINHO PARA SOLDAR
# 84                                                                                      VALVULA MANUAL DE DIAFRAGMA SAUNDERS, TIPO: A, DN80 PN16, COM VOLANTE, FLANGEADA, DIN 2501, EM FERRO FUNDIDO, COM REVESTIMENTO HRL, GRAU Q (KKS: 90PBQ)
# 85                                                                                      VALVULA MANUAL DE DIAFRAGMA SAUNDERS, TIPO: A, DN100 PN16, COM VOLANTE, FLANGEADA, DIN 2501, EM FERRO FUNDIDO, COM REVESTIMENTO HRL, GRAU Q (KKS:90PBQ)
# 86                                                                                          VALVULA ANTI-RETORNO SAUNDERS, TIPO: NX, DN100 PN16, CORPO EM FERRO FUNDIDO, COM REVESTIMENTO HRL, DISCO EM VITON, FLANGEADA, DIN 2501 (KKS: 90PBQ)
# 87                                                                                                                                  FATO IMPERMEAVEL (CASACO + CALCA), AMARELO FLUORESCENTE COM BANDAS REFLECTORAS, TAMANHO S, - EDP PRODUCAO -
# 88         CAPACETE DE PROTECAO COM ISOLAMENTO ELETRICO ATE 1000V, ARNES AJUSTAVEL, RANHURA PARA PROTECCAO AUDITIVA E ROSTO, MARCADOS COM A CLASSE DE PROTECAO E SIMBOLO PROPRIO, COR BRANCA CONFORME FT 1.2.2 NORMA: EN 50365 - EDP PRODUCAO -
# 89                                                                                                                                TRANSFORMADOR DE INTENSIDADE WATTSUD, TIPO: IWR 10K, 7.2/20/60KV, 300/1A, 5VA, CL10P10 (ALTERNADOR/PROTECOES)
# 90                                                                                                                              DESCARREGADOR DE SOBRETENSOES ASEA, TIPO: XAF 50B, TENSAO NOMINAL: 60KV, COM CONTADOR TXA. (KKS: 90AFH11/12/13)
# 91                                         BOTA DE PROTECCAO PARA BAIXAS TEMPERATURAS COM BIQUEIRA E PALMILHA DE ACO, PISO ANTIDERRAPANTE DE DUPLA DENSIDADE PALMILHA ANTI-FUNGOS, NUMERO 38 CONFORME FT 1.6.4 NORMAS: EN 344:1995; EN 345:1992
# 92                                                                                                             CAIXA REDUTORA DE VELOCIDADE MAAG, TIPO: PUVA 3-28, DESENHO MAAG: 770 0383 01 (KKS: 30PAC10AP001.MG01 - SISTEMA AGUA CIRCULACAO)
# 93                                                                                                                                                 CONDENSADOR DE ACOPLAMENTO TRENCH, TIPO: TEC69, CAPACIDADE: 10000PF, TENSAO: 60KV, KKS: 90AF
# 94                                                           PERMUTADOR DE AR/AGUA PARA MOTOR EFACEC, TIPO: AV/RA 560 L8 F, N(o) SERIE: 913406001, POTENCIA: 1650KW, TENSAO: 6KV (MOT ELE VENTILADORES AR SECUNDARIO) 10/20/30/40/HLB10/20AN001
# 95                                                       VENTILADOR PARA MOTOR SEPSA, TIPO: QWG560HB4, TENSAO: 6KV, POTENCIA: 1650KW, (N(o) DE SERIE DE UM DOS MOTORES: 19314/4 -) (MOT ELE VENTILADOR AR SECUNDADIO) 10/20/30/40HLB10/20/AN001
# 96                                                    VENTILADOR PARA MOTOR EFACEC, TIPO: AT2 630 L8 FS4, TENSAO: 6KV, POTENCIA: 1250KW, (N(o) DE SERIE DE UM DOS MOTORES: 913505001) (MOT ELE VENTILADOR AR PRIMARIO) 10/20/30/40HLB30/40AN001
# 97                                                                                   ANEL PESCADOR, REF: Z18-180, P/ MOTOR WEG, TIPO: MGW630A, 5000KW CODIGO DE ARTIGO: 11979459 (KKS: 10/20/30/40XLA20/30AP001) (N(o) Motor: 1015687273 06 12)
# 98                                                                                                                                                         BOBINA TRENCH, INDUTANCIA: 0.2MH, INTENSIDADE: 800A, FREQUENCIA: 250-400HZ KKS: 90AF
# 99                                                                                                                                        ARMARIO DE COMANDO PARA DISJUNTOR EFACEC, TIPO: HPGE 9-14C, UN: 72.5KV, US: 60KV, IN:1250A KKS: 90AFF
#
#      c3   c4   c5   c6   c7
# 0   UN"  NaN  NaN  NaN  NaN
# 1    UN  NaN  NaN  NaN  NaN
# 2    UN  NaN  NaN  NaN  NaN
# 3   PAR  NaN  NaN  NaN  NaN
# 4    UN  NaN  NaN  NaN  NaN
# 5   PAR  NaN  NaN  NaN  NaN
# 6   PAR  NaN  NaN  NaN  NaN
# 7    UN  NaN  NaN  NaN  NaN
# 8   PAR  NaN  NaN  NaN  NaN
# 9   PAR  NaN  NaN  NaN  NaN
# 10   UN  NaN  NaN  NaN  NaN
# 11  PAR  NaN  NaN  NaN  NaN
# 12  PAR  NaN  NaN  NaN  NaN
# 13  PAR  NaN  NaN  NaN  NaN
# 14  PAR  NaN  NaN  NaN  NaN
# 15  PAR  NaN  NaN  NaN  NaN
# 16  PAR  NaN  NaN  NaN  NaN
# 17  PAR  NaN  NaN  NaN  NaN
# 18   CX  NaN  NaN  NaN  NaN
# 19   CX  NaN  NaN  NaN  NaN
# 20  PAR  NaN  NaN  NaN  NaN
# 21  PAR  NaN  NaN  NaN  NaN
# 22   UN  NaN  NaN  NaN  NaN
# 23   UN  NaN  NaN  NaN  NaN
# 24   UN  NaN  NaN  NaN  NaN
# 25  PAR  NaN  NaN  NaN  NaN
# 26   UN  NaN  NaN  NaN  NaN
# 27   UN  NaN  NaN  NaN  NaN
# 28   UN  NaN  NaN  NaN  NaN
# 29   UN  NaN  NaN  NaN  NaN
# 30   UN  NaN  NaN  NaN  NaN
# 31   UN  NaN  NaN  NaN  NaN
# 32   UN  NaN  NaN  NaN  NaN
# 33   UN  NaN  NaN  NaN  NaN
# 34   UN  NaN  NaN  NaN  NaN
# 35   UN  NaN  NaN  NaN  NaN
# 36   UN  NaN  NaN  NaN  NaN
# 37  PAR  NaN  NaN  NaN  NaN
# 38   UN  NaN  NaN  NaN  NaN
# 39  PAR  NaN  NaN  NaN  NaN
# 40  UN"  NaN  NaN  NaN  NaN
# 41   UN  NaN  NaN  NaN  NaN
# 42   UN  NaN  NaN  NaN  NaN
# 43   UN  NaN  NaN  NaN  NaN
# 44   UN  NaN  NaN  NaN  NaN
# 45  PAR  NaN  NaN  NaN  NaN
# 46  PAR  NaN  NaN  NaN  NaN
# 47  UN"  NaN  NaN  NaN  NaN
# 48  UN"  NaN  NaN  NaN  NaN
# 49   UN  NaN  NaN  NaN  NaN
# 50   UN  NaN  NaN  NaN  NaN
# 51   UN  NaN  NaN  NaN  NaN
# 52   UN  NaN  NaN  NaN  NaN
# 53   UN  NaN  NaN  NaN  NaN
# 54   UN  NaN  NaN  NaN  NaN
# 55   UN  NaN  NaN  NaN  NaN
# 56   UN  NaN  NaN  NaN  NaN
# 57   UN  NaN  NaN  NaN  NaN
# 58   UN  NaN  NaN  NaN  NaN
# 59   UN  NaN  NaN  NaN  NaN
# 60   UN  NaN  NaN  NaN  NaN
# 61   UN  NaN  NaN  NaN  NaN
# 62   UN  NaN  NaN  NaN  NaN
# 63   UN  NaN  NaN  NaN  NaN
# 64  UN"  NaN  NaN  NaN  NaN
# 65  UN"  NaN  NaN  NaN  NaN
# 66  PAR  NaN  NaN  NaN  NaN
# 67   UN  NaN  NaN  NaN  NaN
# 68   UN  NaN  NaN  NaN  NaN
# 69  UN"  NaN  NaN  NaN  NaN
# 70  UN"  NaN  NaN  NaN  NaN
# 71  UN"  NaN  NaN  NaN  NaN
# 72  UN"  NaN  NaN  NaN  NaN
# 73  UN"  NaN  NaN  NaN  NaN
# 74   UN  NaN  NaN  NaN  NaN
# 75  UN"  NaN  NaN  NaN  NaN
# 76  UN"  NaN  NaN  NaN  NaN
# 77  UN"  NaN  NaN  NaN  NaN
# 78   UN  NaN  NaN  NaN  NaN
# 79   UN  NaN  NaN  NaN  NaN
# 80   UN  NaN  NaN  NaN  NaN
# 81   UN  NaN  NaN  NaN  NaN
# 82  UN"  NaN  NaN  NaN  NaN
# 83   UN  NaN  NaN  NaN  NaN
# 84   UN  NaN  NaN  NaN  NaN
# 85   UN  NaN  NaN  NaN  NaN
# 86   UN  NaN  NaN  NaN  NaN
# 87   UN  NaN  NaN  NaN  NaN
# 88   UN  NaN  NaN  NaN  NaN
# 89   UN  NaN  NaN  NaN  NaN
# 90   UN  NaN  NaN  NaN  NaN
# 91  UN"  NaN  NaN  NaN  NaN
# 92   UN  NaN  NaN  NaN  NaN
# 93   UN  NaN  NaN  NaN  NaN
# 94   UN  NaN  NaN  NaN  NaN
# 95   UN  NaN  NaN  NaN  NaN
# 96   UN  NaN  NaN  NaN  NaN
# 97   UN  NaN  NaN  NaN  NaN
# 98   UN  NaN  NaN  NaN  NaN
# 99   UN  NaN  NaN  NaN  NaN

# %%
df.count()
# Out:
# c0    206189
# c1    205284
# c2    176667
# c3    206188
# c4        20
# c5        12
# c6         1
# c7         1
# dtype: int64

# %%
df[df.c4.notna()].count()
# Out:
# c0    20
# c1    20
# c2    20
# c3    20
# c4    20
# c5    12
# c6     1
# c7     1
# dtype: int64

# %%
df[df.c4.notna()].head()
# Out:
#               c0                                  c1  \
# 5286  \n10052438           TIRISTOR AEG T290/F-87181
# 5432  \n10052601       TERMOM 0..100C DI=70 B=9,5X65
# 6022  \n10053297           TERMINAL LIGACAO Z006.182
# 7028  \n10054570  OBTURADOR BBC INTROL VALVE N.227 #
# 7029  \n10054571         SEDE BBC INTROL VALVE N.217
#
#                                                                                                                   c2  \
# 5286                                                                                 10BRU10 *ONDULADOR TRISTOR-T290
# 5432                                                       10XAV90AT001-KT01 *SISTEMA OLEO LUBRIFICACAO (TERMOMETRO
# 6022                                                                                10PAB22AA001 TERMINAL DE LIGACAO
# 7028                                                                OBTURADOR PECA N.227 BBC INTROL VALVE DES.N.X100
# 7029  MAP01AA001 *LINHA DE ARRANQUE DA TURBINA(BY-PASS DE ALTA PRESSAO) (SEDE PECA N.217 BBC INTROL VALVE DES.N.X100
#
#                        c3                                     c4     c5  \
# 5286  F1000/EFC62/72/16P6                             F-87181AEG     UN
# 5432               0-100C  ,BOLBO:9,5X65MM DI=70MM MESKO HAUSER)     UN
# 6022                MACHO                        -P/FIM-DE-CURSO  PRATA
# 7028                 1385                                     UN    NaN
# 7029                1385)                                     UN    NaN
#
#              c6   c7
# 5286        NaN  NaN
# 5432        NaN  NaN
# 6022   Z006.182   UN
# 7028        NaN  NaN
# 7029        NaN  NaN

# %% [markdown]
# Getting only the rows that have the correct number of columns.

# %%
mask = df.c4.isna()
df = df.loc[mask,"c0":"c3"]
df.head()
# Out:
#             c0                                     c1  \
# 0  \n"10044864       VENTILADOR SIEMENS PFK 355/102 C
# 1   \n10044865  BOBINA SIEMENS 3AX1101-2F 220VCC (Y2)
# 2   \n10044868            PRESSOSTATO TRAFAG 8730.101
# 3   \n10044869        PALMILHA ASTRA GEL INSOLE TM 45
# 4   \n10044870           BOBINA ELETRO FREIO ELEVADOR
#
#                                                                                                                                                                                        c2  \
# 0                                                           VENTILADOR SIEMENS, REF: PFK 355/102 C, POTENCIA: 150W, TENSAO: 230V; 50/60HZ (PECA DE RESERVA DA CELA NXAIR P, VILA NOVA G4)
# 1                                      BOBINE SIEMENS, REF: 3AX1101-2F, TENSAO: 220VCC, UTILIZACAO: COMO BOBINE DE ABERTURA POR ENVIO DE TENSAO (Y2), PARA DISJUNTORES SIEMENS, TIPO: 3AK
# 2  PRESSOSTATO TRAFAG, TIPO: 8730.101, CONTROLADOR DE PRESSAO E DENSIDADE DE SF6, FAIXA DE PRESSAO: -1 A 10BAR, FAIXA DE TEMPERATURA: -25 A +55(o)C, PRESSAO FUNCIONAMENTO: 20(o)C/5.7BAR
# 3                                                                                                              PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 45
# 4                                                                               BOBINA ELETRO FREIO DO ELEVADOR SALAMONDE DIAMETRO INTERIOR: 80MM, DIAMETRO EXTERIOR: 125MM, ALTURA 110MM
#
#     c3
# 0  UN"
# 1   UN
# 2   UN
# 3  PAR
# 4   UN

# %% [markdown]
# Replacing some garbage characters that were remained.

# %%
df.c0 = df.c0.str.replace("\n", "")
df.c0 = df.c0.str.replace('"', "")
df.c3 = df.c3.str.replace('"', "")
df.head()
# Out:
#          c0                                     c1  \
# 0  10044864       VENTILADOR SIEMENS PFK 355/102 C
# 1  10044865  BOBINA SIEMENS 3AX1101-2F 220VCC (Y2)
# 2  10044868            PRESSOSTATO TRAFAG 8730.101
# 3  10044869        PALMILHA ASTRA GEL INSOLE TM 45
# 4  10044870           BOBINA ELETRO FREIO ELEVADOR
#
#                                                                                                                                                                                        c2  \
# 0                                                           VENTILADOR SIEMENS, REF: PFK 355/102 C, POTENCIA: 150W, TENSAO: 230V; 50/60HZ (PECA DE RESERVA DA CELA NXAIR P, VILA NOVA G4)
# 1                                      BOBINE SIEMENS, REF: 3AX1101-2F, TENSAO: 220VCC, UTILIZACAO: COMO BOBINE DE ABERTURA POR ENVIO DE TENSAO (Y2), PARA DISJUNTORES SIEMENS, TIPO: 3AK
# 2  PRESSOSTATO TRAFAG, TIPO: 8730.101, CONTROLADOR DE PRESSAO E DENSIDADE DE SF6, FAIXA DE PRESSAO: -1 A 10BAR, FAIXA DE TEMPERATURA: -25 A +55(o)C, PRESSAO FUNCIONAMENTO: 20(o)C/5.7BAR
# 3                                                                                                              PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 45
# 4                                                                               BOBINA ELETRO FREIO DO ELEVADOR SALAMONDE DIAMETRO INTERIOR: 80MM, DIAMETRO EXTERIOR: 125MM, ALTURA 110MM
#
#     c3
# 0   UN
# 1   UN
# 2   UN
# 3  PAR
# 4   UN

# %%
df.shape
# Out:
# (206169, 4)

# %% [markdown]
# Finishing with some more meaningfull column names.

# %%
col_names = [
    "material", "txt_brv_material",
    "texto_dados_basicos", "um_basica"
]
    
df.columns = col_names
df.head()
# Out:
#    material                       txt_brv_material  \
# 0  10044864       VENTILADOR SIEMENS PFK 355/102 C
# 1  10044865  BOBINA SIEMENS 3AX1101-2F 220VCC (Y2)
# 2  10044868            PRESSOSTATO TRAFAG 8730.101
# 3  10044869        PALMILHA ASTRA GEL INSOLE TM 45
# 4  10044870           BOBINA ELETRO FREIO ELEVADOR
#
#                                                                                                                                                                       texto_dados_basicos  \
# 0                                                           VENTILADOR SIEMENS, REF: PFK 355/102 C, POTENCIA: 150W, TENSAO: 230V; 50/60HZ (PECA DE RESERVA DA CELA NXAIR P, VILA NOVA G4)
# 1                                      BOBINE SIEMENS, REF: 3AX1101-2F, TENSAO: 220VCC, UTILIZACAO: COMO BOBINE DE ABERTURA POR ENVIO DE TENSAO (Y2), PARA DISJUNTORES SIEMENS, TIPO: 3AK
# 2  PRESSOSTATO TRAFAG, TIPO: 8730.101, CONTROLADOR DE PRESSAO E DENSIDADE DE SF6, FAIXA DE PRESSAO: -1 A 10BAR, FAIXA DE TEMPERATURA: -25 A +55(o)C, PRESSAO FUNCIONAMENTO: 20(o)C/5.7BAR
# 3                                                                                                              PALMILHA ASTRA GEL INSOLE, PARA CALCADO DE PROTECCAO INDIVIDUAL TAMANHO 45
# 4                                                                               BOBINA ELETRO FREIO DO ELEVADOR SALAMONDE DIAMETRO INTERIOR: 80MM, DIAMETRO EXTERIOR: 125MM, ALTURA 110MM
#
#   um_basica
# 0        UN
# 1        UN
# 2        UN
# 3       PAR
# 4        UN

# %%
file = PATH + "/data/intermediate/matList_pt.csv"

df.to_csv(file,
          sep="|",
          header=True,
          index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-edb5727f8bb0> in <module>
# ----> 1 file = PATH + "/data/intermediate/matList_pt.csv"
#       2
#       3 df.to_csv(file,
#       4           sep="|",
#       5           header=True,
#
# NameError: name 'PATH' is not defined
